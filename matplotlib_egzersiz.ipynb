# %%
import matplotlib.pyplot as plt

# %%
# 1-100 kadar değerler için x^2 fonksiyonunun grafiğini çizdir.

x = []
y = []

i=1
while i<=100:
    x.append(i)
    y.append(i*i)
    i = i+1


plt.title("x^2")
plt.grid()
plt.plot(x,y)
plt.show()
